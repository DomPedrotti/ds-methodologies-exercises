# %%
import warnings
warnings.filterwarnings("ignore")

# Wrangling
import pandas as pd
import numpy as np

# Exploring
import scipy.stats as stats

# Visualizing
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# default pandas decimal number display format
pd.options.display.float_format = '{:20,.2f}'.format

from env import get_db_url
import acquire
import summarize
import prepare

# %%
zillow = acquire.get_zillow_data()
zillow = prepare.handle_missing_values(prepare.get_single_unit_properties(zillow))

# %%
zillow.dropna(inplace=True)
summarize.df_summary(zillow)
# Out:
# --- Shape: (50569, 28)
# --- Info
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50569 entries, 0 to 77579
# Data columns (total 28 columns):
# propertylandusetypeid           50569 non-null float64
# parcelid                        50569 non-null int64
# logerror                        50569 non-null float64
# transactiondate                 50569 non-null object
# bathroomcnt                     50569 non-null float64
# bedroomcnt                      50569 non-null float64
# calculatedbathnbr               50569 non-null float64
# calculatedfinishedsquarefeet    50569 non-null float64
# finishedsquarefeet12            50569 non-null float64
# fips                            50569 non-null float64
# fullbathcnt                     50569 non-null float64
# latitude                        50569 non-null float64
# longitude                       50569 non-null float64
# lotsizesquarefeet               50569 non-null float64
# propertycountylandusecode       50569 non-null object
# rawcensustractandblock          50569 non-null float64
# regionidcity                    50569 non-null float64
# regionidcounty                  50569 non-null float64
# regionidzip                     50569 non-null float64
# roomcnt                         50569 non-null float64
# yearbuilt                       50569 non-null float64
# structuretaxvaluedollarcnt      50569 non-null float64
# taxvaluedollarcnt               50569 non-null float64
# assessmentyear                  50569 non-null float64
# landtaxvaluedollarcnt           50569 non-null float64
# taxamount                       50569 non-null float64
# censustractandblock             50569 non-null float64
# propertylandusedesc             50569 non-null object
# dtypes: float64(24), int64(1), object(3)
# memory usage: 11.2+ MB
# --- Descriptions
#         propertylandusetypeid             parcelid             logerror  \
# count               50,569.00            50,569.00            50,569.00
# unique                    nan                  nan                  nan
# top                       nan                  nan                  nan
# freq                      nan                  nan                  nan
# mean                   261.00        12,960,548.33                 0.02
# std                      0.19         2,196,238.57                 0.18
# min                    261.00        10,711,855.00                -4.66
# 25%                    261.00        11,529,075.00                -0.02
# 50%                    261.00        12,582,762.00                 0.01
# 75%                    261.00        14,129,451.00                 0.04
# max                    275.00       162,960,814.00                 5.26
#
#        transactiondate          bathroomcnt           bedroomcnt  \
# count            50569            50,569.00            50,569.00
# unique             258                  nan                  nan
# top         2017-06-30                  nan                  nan
# freq               779                  nan                  nan
# mean               NaN                 2.29                 3.30
# std                NaN                 1.00                 0.93
# min                NaN                 1.00                 0.00
# 25%                NaN                 2.00                 3.00
# 50%                NaN                 2.00                 3.00
# 75%                NaN                 3.00                 4.00
# max                NaN                13.00                11.00
#
#           calculatedbathnbr  calculatedfinishedsquarefeet  \
# count             50,569.00                     50,569.00
# unique                  nan                           nan
# top                     nan                           nan
# freq                    nan                           nan
# mean                   2.29                      1,912.08
# std                    1.00                        989.72
# min                    1.00                        152.00
# 25%                    2.00                      1,268.00
# 50%                    2.00                      1,651.00
# 75%                    3.00                      2,286.00
# max                   13.00                     21,929.00
#
#         finishedsquarefeet12                 fips  ...          regionidzip  \
# count              50,569.00            50,569.00  ...            50,569.00
# unique                   nan                  nan  ...                  nan
# top                      nan                  nan  ...                  nan
# freq                     nan                  nan  ...                  nan
# mean                1,912.08             6,049.21  ...            96,632.28
# std                   989.72                21.19  ...             4,489.99
# min                   152.00             6,037.00  ...            95,982.00
# 25%                 1,268.00             6,037.00  ...            96,203.00
# 50%                 1,651.00             6,037.00  ...            96,414.00
# 75%                 2,286.00             6,059.00  ...            96,996.00
# max                21,929.00             6,111.00  ...           399,675.00
#
#                     roomcnt            yearbuilt  structuretaxvaluedollarcnt  \
# count             50,569.00            50,569.00                   50,569.00
# unique                  nan                  nan                         nan
# top                     nan                  nan                         nan
# freq                    nan                  nan                         nan
# mean                   1.91             1,963.02                  193,144.36
# std                    3.16                22.78                  250,696.61
# min                    0.00             1,878.00                      148.00
# 25%                    0.00             1,950.00                   76,836.00
# 50%                    0.00             1,960.00                  130,572.00
# 75%                    5.00             1,978.00                  221,324.00
# max                   15.00             2,016.00                9,164,901.00
#
#           taxvaluedollarcnt       assessmentyear  landtaxvaluedollarcnt  \
# count             50,569.00            50,569.00              50,569.00
# unique                  nan                  nan                    nan
# top                     nan                  nan                    nan
# freq                    nan                  nan                    nan
# mean             521,938.77             2,016.00             328,794.40
# std              712,847.77                 0.00             519,955.26
# min                3,254.00             2,016.00                 161.00
# 25%              192,000.00             2,016.00              74,248.00
# 50%              369,569.00             2,016.00             216,456.00
# 75%              610,628.00             2,016.00             406,421.00
# max           25,381,250.00             2,016.00          22,335,500.00
#
#                   taxamount    censustractandblock        propertylandusedesc
# count             50,569.00              50,569.00                      50569
# unique                  nan                    nan                          2
# top                     nan                    nan  Single Family Residential
# freq                    nan                    nan                      50560
# mean               6,345.92  60,503,516,485,254.40                        NaN
# std                8,261.96   1,890,704,989,380.66                        NaN
# min                   49.18  60,371,011,101,000.00                        NaN
# 25%                2,636.64  60,374,006,021,007.00                        NaN
# 50%                4,595.48  60,376,028,021,015.00                        NaN
# 75%                7,251.28  60,590,423,281,019.00                        NaN
# max              290,998.06 483,030,105,084,015.00                        NaN
#
# [11 rows x 28 columns]
# --- Nulls By Column
#                               num_rows_missing     pct_rows_missing
# propertylandusetypeid                        0                 0.00
# parcelid                                     0                 0.00
# logerror                                     0                 0.00
# transactiondate                              0                 0.00
# bathroomcnt                                  0                 0.00
# bedroomcnt                                   0                 0.00
# calculatedbathnbr                            0                 0.00
# calculatedfinishedsquarefeet                 0                 0.00
# finishedsquarefeet12                         0                 0.00
# fips                                         0                 0.00
# fullbathcnt                                  0                 0.00
# latitude                                     0                 0.00
# longitude                                    0                 0.00
# lotsizesquarefeet                            0                 0.00
# propertycountylandusecode                    0                 0.00
# rawcensustractandblock                       0                 0.00
# regionidcity                                 0                 0.00
# regionidcounty                               0                 0.00
# regionidzip                                  0                 0.00
# roomcnt                                      0                 0.00
# yearbuilt                                    0                 0.00
# structuretaxvaluedollarcnt                   0                 0.00
# taxvaluedollarcnt                            0                 0.00
# assessmentyear                               0                 0.00
# landtaxvaluedollarcnt                        0                 0.00
# taxamount                                    0                 0.00
# censustractandblock                          0                 0.00
# propertylandusedesc                          0                 0.00
# --- Nulls By Row
#    num_cols_missing     pct_cols_missing  num_rows
# 0                 0                 0.00     50569
# --- Value Counts
# (260.985, 262.4]                              50560
# (262.4, 263.8]                                    0
# (263.8, 265.2]                                    0
# (265.2, 266.6]                                    0
# (266.6, 268.0]                                    0
# (268.0, 269.4]                                    0
# (269.4, 270.8]                                    0
# (270.8, 272.2]                                    0
# (272.2, 273.6]                                    0
# (273.6, 275.0]                                    9
# (10559606.04, 25936750.9]                     50565
# (25936750.9, 41161646.8]                          0
# (41161646.8, 56386542.7]                          0
# (56386542.7, 71611438.6]                          0
# (71611438.6, 86836334.5]                          0
# (86836334.5, 102061230.4]                         0
# (102061230.4, 117286126.3]                        0
# (117286126.3, 132511022.2]                        0
# (132511022.2, 147735918.1]                        0
# (147735918.1, 162960814.0]                        4
# (-4.666, -3.664]                                  2
# (-3.664, -2.672]                                  0
# (-2.672, -1.68]                                  25
# (-1.68, -0.688]                                  99
# (-0.688, 0.304]                               49151
# (0.304, 1.296]                                 1167
# (1.296, 2.287]                                   72
# (2.287, 3.279]                                   51
# (3.279, 4.271]                                    1
# (4.271, 5.263]                                    1
#                                               ...
# (4467228.8, 6700762.7]                           84
# (6700762.7, 8934296.6]                           15
# (8934296.6, 11167830.5]                          11
# (11167830.5, 13401364.4]                          4
# (13401364.4, 15634898.3]                          2
# (15634898.3, 17868432.2]                          1
# (17868432.2, 20101966.1]                          2
# (20101966.1, 22335500.0]                          1
# (-241.77, 29144.068]                          49751
# (29144.068, 58238.956]                          632
# (58238.956, 87333.844]                          126
# (87333.844, 116428.732]                          28
# (116428.732, 145523.62]                          13
# (145523.62, 174618.508]                           7
# (174618.508, 203713.396]                          5
# (203713.396, 232808.284]                          3
# (232808.284, 261903.172]                          0
# (261903.172, 290998.06]                           4
# (59948352007016.984, 102636920499301.5]       50568
# (102636920499301.5, 144902829897603.0]            0
# (144902829897603.0, 187168739295904.5]            0
# (187168739295904.5, 229434648694206.03]           0
# (229434648694206.03, 271700558092507.5]           0
# (271700558092507.5, 313966467490809.0]            0
# (313966467490809.0, 356232376889110.5]            0
# (356232376889110.5, 398498286287411.94]           0
# (398498286287411.94, 440764195685713.5]           0
# (440764195685713.5, 483030105084015.0]            1
# Single Family Residential                     50560
# Manufactured, Modular, Prefabricated Homes        9
# Length: 534, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.scatterplot('longitude', 'latitude', data = zillow, hue = 'fips', palette=['red','yellow','blue'], alpha = .3)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

import split_scale as ss
import wrangle as wgl

# %%
df = ss.df
df.total_charges = df.total_charges.apply(float)

# %%
x = df[['tenure', 'monthly_charges']]
y = df[['total_charges']]
x ,y =  ss.split_my_data(x,y)
print (x['train'].head())
print(y['train'].head())
# Out:
#       tenure  monthly_charges
# 119       70            75.50
# 1424      55            20.30
# 385       65           109.05
# 1140      70            98.30
# 1504      71           116.25
#       total_charges
# 119         5212.65
# 1424        1079.05
# 385         7108.20
# 1140        6859.50
# 1504        8564.75

# %%
def plot_variable_pairs(dataframe):
    g = sns.PairGrid(dataframe)
    g.map_diag(plt.hist)
    g.map_offdiag(plt.scatter);

# %%
x_y = x['train'].join(y['train'])
x_y[['tenure', 'total_charges']].head()
# Out:
#       tenure  total_charges
# 119       70        5212.65
# 1424      55        1079.05
# 385       65        7108.20
# 1140      70        6859.50
# 1504      71        8564.75

# %%
plot_variable_pairs(x_y)

# %%
def months_to_years(tenure_months, df):
    df['tenure_months'] = tenure_months/12
    return df

# %%
months_to_years(x['train']['tenure'], x['train'] ).head()
# Out:
#       tenure  monthly_charges  tenure_months
# 119       70            75.50       5.833333
# 1424      55            20.30       4.583333
# 385       65           109.05       5.416667
# 1140      70            98.30       5.833333
# 1504      71           116.25       5.916667
